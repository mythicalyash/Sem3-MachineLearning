# %%
! pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 4.5 MB/s  0:00:02 eta 0:00:01m
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
arr = np.array([[16.99, 1.01], [10.34, 1.66], [21.01, 3.50]])
print(arr[1, 1])
# Out:
# 1.66

# %%
tbl = pd.DataFrame(arr, columns=['total_bill', 'tip'])
print(tbl.loc[1, 'tip']) 
print(tbl)
# Out:
# 1.66
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50

# %%
# pd.dataframe - from a dictionary

restaurant = {
'Table':[1,2,3],
'Total Bill':[16.99, 10.34, 21.01],
'waiter':['amit','sachin','rohit']
}

df = pd.DataFrame(restaurant)
print(df)
print(type(df))

print(df['Table'])
print(type(df['Table']))
# Out:
#    Table  Total Bill  waiter
# 0      1       16.99    amit
# 1      2       10.34  sachin
# 2      3       21.01   rohit
# <class 'pandas.DataFrame'>
# 0    1
# 1    2
# 2    3
# Name: Table, dtype: int64
# <class 'pandas.Series'>
